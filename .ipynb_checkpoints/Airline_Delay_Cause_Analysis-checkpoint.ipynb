# %% [markdown]
# # Tahim Bhuiya
#
# # Data Wrangling & Exploratory Data Analysis

# %%
import pandas as pd
df = pd.read_csv('Airline_Delay_Cause.csv') #dataset that will be used
df
# Out:
#         year  month carrier          carrier_name airport  \
# 0       2022      5      9E     Endeavor Air Inc.     ABE
# 1       2022      5      9E     Endeavor Air Inc.     ABY
# 2       2022      5      9E     Endeavor Air Inc.     ACK
# 3       2022      5      9E     Endeavor Air Inc.     AEX
# 4       2022      5      9E     Endeavor Air Inc.     AGS
# ...      ...    ...     ...                   ...     ...
# 318012  2003      6      DL  Delta Air Lines Inc.     SEA
# 318013  2003      6      DL  Delta Air Lines Inc.     SFO
# 318014  2003      6      DL  Delta Air Lines Inc.     SJC
# 318015  2003      6      DL  Delta Air Lines Inc.     SJU
# 318016  2003      6      DL  Delta Air Lines Inc.     SLC
#
#                                              airport_name  arr_flights  \
# 0       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        136.0
# 1                  Albany, GA: Southwest Georgia Regional         91.0
# 2                       Nantucket, MA: Nantucket Memorial         19.0
# 3                Alexandria, LA: Alexandria International         88.0
# 4             Augusta, GA: Augusta Regional at Bush Field        181.0
# ...                                                   ...          ...
# 318012          Seattle, WA: Seattle/Tacoma International        480.0
# 318013     San Francisco, CA: San Francisco International        505.0
# 318014  San Jose, CA: Norman Y. Mineta San Jose Intern...        146.0
# 318015       San Juan, PR: Luis Munoz Marin International         95.0
# 318016   Salt Lake City, UT: Salt Lake City International       3466.0
#
#         arr_del15  carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  \
# 0             7.0        5.95        0.00  ...          0.0              1.00
# 1            16.0        7.38        0.00  ...          0.0              6.09
# 2             2.0        0.13        0.00  ...          0.0              0.88
# 3            14.0        7.26        0.76  ...          0.0              1.64
# 4            19.0       13.84        0.00  ...          0.0              2.09
# ...           ...         ...         ...  ...          ...               ...
# 318012       84.0       25.69        3.09  ...          0.0             21.26
# 318013      111.0       21.78        2.24  ...          0.0             13.17
# 318014       36.0        6.99        0.00  ...          0.0              2.15
# 318015       13.0        3.66        0.00  ...          0.0              1.42
# 318016      454.0      121.15        7.61  ...          1.0            102.33
#
#         arr_cancelled  arr_diverted  arr_delay  carrier_delay  weather_delay  \
# 0                 0.0           0.0      255.0          222.0            0.0
# 1                 0.0           0.0      884.0          351.0            0.0
# 2                 1.0           0.0      138.0            4.0            0.0
# 3                 0.0           0.0      947.0          585.0           35.0
# 4                 0.0           0.0      808.0          662.0            0.0
# ...               ...           ...        ...            ...            ...
# 318012            0.0           0.0     3744.0          978.0          164.0
# 318013            3.0           0.0     4284.0         1376.0          138.0
# 318014            0.0           0.0      896.0          205.0            0.0
# 318015            0.0           0.0      367.0          120.0            0.0
# 318016            9.0           0.0    16853.0         5384.0          306.0
#
#         nas_delay  security_delay  late_aircraft_delay
# 0             4.0             0.0                 29.0
# 1            81.0             0.0                452.0
# 2           106.0             0.0                 28.0
# 3           125.0             0.0                202.0
# 4            87.0             0.0                 59.0
# ...           ...             ...                  ...
# 318012     1023.0             0.0               1579.0
# 318013     2132.0             0.0                638.0
# 318014      607.0             0.0                 84.0
# 318015      210.0             0.0                 37.0
# 318016     5686.0            28.0               5449.0
#
# [318017 rows x 21 columns]

# %%
df.columns # print the columns
# Out:
# Index(['year', 'month', 'carrier', 'carrier_name', 'airport', 'airport_name',
#        'arr_flights', 'arr_del15', 'carrier_ct', 'weather_ct', 'nas_ct',
#        'security_ct', 'late_aircraft_ct', 'arr_cancelled', 'arr_diverted',
#        'arr_delay', 'carrier_delay', 'weather_delay', 'nas_delay',
#        'security_delay', 'late_aircraft_delay'],
#       dtype='object')

# %%
df.shape # print the number of rows and columns
# Out:
# (318017, 21)

# %% [markdown]
# There are 318017 observations and 21 columns

# %%
df.dtypes # print data types
# Out:
# year                     int64
# month                    int64
# carrier                 object
# carrier_name            object
# airport                 object
# airport_name            object
# arr_flights            float64
# arr_del15              float64
# carrier_ct             float64
# weather_ct             float64
# nas_ct                 float64
# security_ct            float64
# late_aircraft_ct       float64
# arr_cancelled          float64
# arr_diverted           float64
# arr_delay              float64
# carrier_delay          float64
# weather_delay          float64
# nas_delay              float64
# security_delay         float64
# late_aircraft_delay    float64
# dtype: object

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### •	Check if there are missing values. Then, handle missing values (e.g., removal, replacing with the average value, etc.)

# %%
df = df.dropna() # remove rows containing nan values

# %%
df.shape
# Out:
# (317261, 21)

# %% [markdown]
# There were 261 rows with missing values that were removed so far

# %% [markdown]
# ### •	Now checking for duplicated rows. If there is, remove them.

# %%
df = df.drop_duplicates(keep='first') # drop duplicated rows, keep the first occurance

# %%
df.head()
# Out:
#    year  month carrier       carrier_name airport  \
# 0  2022      5      9E  Endeavor Air Inc.     ABE
# 1  2022      5      9E  Endeavor Air Inc.     ABY
# 2  2022      5      9E  Endeavor Air Inc.     ACK
# 3  2022      5      9E  Endeavor Air Inc.     AEX
# 4  2022      5      9E  Endeavor Air Inc.     AGS
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        136.0        7.0
# 1             Albany, GA: Southwest Georgia Regional         91.0       16.0
# 2                  Nantucket, MA: Nantucket Memorial         19.0        2.0
# 3           Alexandria, LA: Alexandria International         88.0       14.0
# 4        Augusta, GA: Augusta Regional at Bush Field        181.0       19.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        5.95        0.00  ...          0.0              1.00            0.0
# 1        7.38        0.00  ...          0.0              6.09            0.0
# 2        0.13        0.00  ...          0.0              0.88            1.0
# 3        7.26        0.76  ...          0.0              1.64            0.0
# 4       13.84        0.00  ...          0.0              2.09            0.0
#
#    arr_diverted  arr_delay  carrier_delay  weather_delay  nas_delay  \
# 0           0.0      255.0          222.0            0.0        4.0
# 1           0.0      884.0          351.0            0.0       81.0
# 2           0.0      138.0            4.0            0.0      106.0
# 3           0.0      947.0          585.0           35.0      125.0
# 4           0.0      808.0          662.0            0.0       87.0
#
#    security_delay  late_aircraft_delay
# 0             0.0                 29.0
# 1             0.0                452.0
# 2             0.0                 28.0
# 3             0.0                202.0
# 4             0.0                 59.0
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#         year  month carrier          carrier_name airport  \
# 318012  2003      6      DL  Delta Air Lines Inc.     SEA
# 318013  2003      6      DL  Delta Air Lines Inc.     SFO
# 318014  2003      6      DL  Delta Air Lines Inc.     SJC
# 318015  2003      6      DL  Delta Air Lines Inc.     SJU
# 318016  2003      6      DL  Delta Air Lines Inc.     SLC
#
#                                              airport_name  arr_flights  \
# 318012          Seattle, WA: Seattle/Tacoma International        480.0
# 318013     San Francisco, CA: San Francisco International        505.0
# 318014  San Jose, CA: Norman Y. Mineta San Jose Intern...        146.0
# 318015       San Juan, PR: Luis Munoz Marin International         95.0
# 318016   Salt Lake City, UT: Salt Lake City International       3466.0
#
#         arr_del15  carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  \
# 318012       84.0       25.69        3.09  ...          0.0             21.26
# 318013      111.0       21.78        2.24  ...          0.0             13.17
# 318014       36.0        6.99        0.00  ...          0.0              2.15
# 318015       13.0        3.66        0.00  ...          0.0              1.42
# 318016      454.0      121.15        7.61  ...          1.0            102.33
#
#         arr_cancelled  arr_diverted  arr_delay  carrier_delay  weather_delay  \
# 318012            0.0           0.0     3744.0          978.0          164.0
# 318013            3.0           0.0     4284.0         1376.0          138.0
# 318014            0.0           0.0      896.0          205.0            0.0
# 318015            0.0           0.0      367.0          120.0            0.0
# 318016            9.0           0.0    16853.0         5384.0          306.0
#
#         nas_delay  security_delay  late_aircraft_delay
# 318012     1023.0             0.0               1579.0
# 318013     2132.0             0.0                638.0
# 318014      607.0             0.0                 84.0
# 318015      210.0             0.0                 37.0
# 318016     5686.0            28.0               5449.0
#
# [5 rows x 21 columns]

# %%
df.shape # let's check how many rows we removed
# Out:
# (317261, 21)

# %% [markdown]
# No additional rows were removed, which means there weren't any duplicated rows.

# %% [markdown]
# Renaming a column

# %%
df = df.rename(columns={
    "arr_del15": "num_delayed_flights"
})

# %%
df.head() #Checking
# Out:
#    year  month carrier       carrier_name airport  \
# 0  2022      5      9E  Endeavor Air Inc.     ABE
# 1  2022      5      9E  Endeavor Air Inc.     ABY
# 2  2022      5      9E  Endeavor Air Inc.     ACK
# 3  2022      5      9E  Endeavor Air Inc.     AEX
# 4  2022      5      9E  Endeavor Air Inc.     AGS
#
#                                         airport_name  arr_flights  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        136.0
# 1             Albany, GA: Southwest Georgia Regional         91.0
# 2                  Nantucket, MA: Nantucket Memorial         19.0
# 3           Alexandria, LA: Alexandria International         88.0
# 4        Augusta, GA: Augusta Regional at Bush Field        181.0
#
#    num_delayed_flights  carrier_ct  weather_ct  ...  security_ct  \
# 0                  7.0        5.95        0.00  ...          0.0
# 1                 16.0        7.38        0.00  ...          0.0
# 2                  2.0        0.13        0.00  ...          0.0
# 3                 14.0        7.26        0.76  ...          0.0
# 4                 19.0       13.84        0.00  ...          0.0
#
#    late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  carrier_delay  \
# 0              1.00            0.0           0.0      255.0          222.0
# 1              6.09            0.0           0.0      884.0          351.0
# 2              0.88            1.0           0.0      138.0            4.0
# 3              1.64            0.0           0.0      947.0          585.0
# 4              2.09            0.0           0.0      808.0          662.0
#
#    weather_delay  nas_delay  security_delay  late_aircraft_delay
# 0            0.0        4.0             0.0                 29.0
# 1            0.0       81.0             0.0                452.0
# 2            0.0      106.0             0.0                 28.0
# 3           35.0      125.0             0.0                202.0
# 4            0.0       87.0             0.0                 59.0
#
# [5 rows x 21 columns]

# %% [markdown]
# Changed the name of the column that gives the number of delayed flights to an easier one.

# %% [markdown]
# Converting one variable to a different data type

# %%
df["carrier_name"] = df["carrier_name"].astype("category")
df.dtypes
# Out:
# year                      int64
# month                     int64
# carrier                  object
# carrier_name           category
# airport                  object
# airport_name             object
# arr_flights             float64
# num_delayed_flights     float64
# carrier_ct              float64
# weather_ct              float64
# nas_ct                  float64
# security_ct             float64
# late_aircraft_ct        float64
# arr_cancelled           float64
# arr_diverted            float64
# arr_delay               float64
# carrier_delay           float64
# weather_delay           float64
# nas_delay               float64
# security_delay          float64
# late_aircraft_delay     float64
# dtype: object

# %% [markdown]
# Converted carrier_name from an object type to a categorical type to better represent airline groups during analysis.

# %% [markdown]
# ### •	Creating new variable.

# %%
df["delay_rate"] = df["num_delayed_flights"] / df["arr_flights"]
df.head()
# Out:
#    year  month carrier       carrier_name airport  \
# 0  2022      5      9E  Endeavor Air Inc.     ABE
# 1  2022      5      9E  Endeavor Air Inc.     ABY
# 2  2022      5      9E  Endeavor Air Inc.     ACK
# 3  2022      5      9E  Endeavor Air Inc.     AEX
# 4  2022      5      9E  Endeavor Air Inc.     AGS
#
#                                         airport_name  arr_flights  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        136.0
# 1             Albany, GA: Southwest Georgia Regional         91.0
# 2                  Nantucket, MA: Nantucket Memorial         19.0
# 3           Alexandria, LA: Alexandria International         88.0
# 4        Augusta, GA: Augusta Regional at Bush Field        181.0
#
#    num_delayed_flights  carrier_ct  weather_ct  ...  late_aircraft_ct  \
# 0                  7.0        5.95        0.00  ...              1.00
# 1                 16.0        7.38        0.00  ...              6.09
# 2                  2.0        0.13        0.00  ...              0.88
# 3                 14.0        7.26        0.76  ...              1.64
# 4                 19.0       13.84        0.00  ...              2.09
#
#    arr_cancelled  arr_diverted  arr_delay  carrier_delay  weather_delay  \
# 0            0.0           0.0      255.0          222.0            0.0
# 1            0.0           0.0      884.0          351.0            0.0
# 2            1.0           0.0      138.0            4.0            0.0
# 3            0.0           0.0      947.0          585.0           35.0
# 4            0.0           0.0      808.0          662.0            0.0
#
#    nas_delay  security_delay  late_aircraft_delay  delay_rate
# 0        4.0             0.0                 29.0    0.051471
# 1       81.0             0.0                452.0    0.175824
# 2      106.0             0.0                 28.0    0.105263
# 3      125.0             0.0                202.0    0.159091
# 4       87.0             0.0                 59.0    0.104972
#
# [5 rows x 22 columns]

# %% [markdown]
# Added a delay rate variable to show the proportion of arriving flights that were delayed.

# %% [markdown]
# ### •	Create two smaller dataframes based on a condition

# %%
high_delay_df = df[df["delay_rate"] > 0.20]

# %% [markdown]
# Records where more than 20% of flights were delayed

# %%
low_delay_df = df[df["delay_rate"] <= 0.20]

# %% [markdown]
# Records where less than 20% of flights were delayed

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df[["arr_delay"]].describe()
# Out:
#            arr_delay
# count  317261.000000
# mean     4213.310599
# std     12523.626528
# min         0.000000
# 25%       437.000000
# 50%      1203.000000
# 75%      3083.000000
# max    433687.000000

# %% [markdown]
# This describes total arrival delay in minutes and median is the 50% label

# %%
df[["delay_rate"]].describe()
# Out:
#           delay_rate
# count  317261.000000
# mean        0.197759
# std         0.112308
# min         0.000000
# 25%         0.122302
# 50%         0.184896
# 75%         0.258065
# max         1.000000

# %% [markdown]
# This describes the new variable which records the proportion of delayed flights

# %% [markdown]
# ### •	Getting the frequency table of two categorical variables.

# %%
df["carrier_name"].value_counts()
# Out:
# carrier_name
# SkyWest Airlines Inc.           38038
# Delta Air Lines Inc.            27518
# ExpressJet Airlines Inc.        24487
# American Airlines Inc.          19770
# United Air Lines Inc.           19096
# Southwest Airlines Co.          17576
# American Eagle Airlines Inc.    15399
# Mesa Airlines Inc.              14483
# Alaska Airlines Inc.            12933
# Frontier Airlines Inc.          12275
# Atlantic Southeast Airlines     12158
# JetBlue Airways                 11572
# US Airways Inc.                 10692
# Envoy Air                        8979
# Northwest Airlines Inc.          8061
# Comair Inc.                      7685
# AirTran Airways Corporation      6955
# Continental Air Lines Inc.       6908
# Pinnacle Airlines Inc.           6434
# Allegiant Air                    6369
# Endeavor Air Inc.                5509
# Republic Airline                 4425
# PSA Airlines Inc.                4217
# Spirit Air Lines                 3788
# Hawaiian Airlines Inc.           3579
# America West Airlines Inc.       1579
# Virgin America                   1425
# ExpressJet Airlines LLC          1419
# Atlantic Coast Airlines          1253
# ATA Airlines d/b/a ATA            918
# Horizon Air                       838
# Independence Air                  670
# Aloha Airlines Inc.               253
# Name: count, dtype: int64

# %%
df["airport"].value_counts()
# Out:
# airport
# DTW    3022
# LAX    2988
# LAS    2978
# MCI    2963
# PIT    2946
#        ...
# MKC       1
# YNG       1
# FNL       1
# SKA       1
# CBM       1
# Name: count, Length: 418, dtype: int64

# %% [markdown]
# Gives value counts for each airport

# %% [markdown]
# ### •	Now getting the average value for 2 numerical variables per category using the groupby() function.

# %%
df.groupby("carrier_name")[["arr_delay"]].mean().reset_index()
# Out:
# C:\Users\tahim\AppData\Local\Temp\ipykernel_9636\3411659727.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("carrier_name")[["arr_delay"]].mean().reset_index()
#                     carrier_name     arr_delay
# 0         ATA Airlines d/b/a ATA   2225.654684
# 1    AirTran Airways Corporation   3926.668871
# 2           Alaska Airlines Inc.   2078.584938
# 3                  Allegiant Air   1161.215104
# 4            Aloha Airlines Inc.   1037.237154
# 5     America West Airlines Inc.   2713.200760
# 6         American Airlines Inc.   8029.828781
# 7   American Eagle Airlines Inc.   4183.376843
# 8        Atlantic Coast Airlines   3913.144453
# 9    Atlantic Southeast Airlines   2992.291413
# 10                   Comair Inc.   2754.490696
# 11    Continental Air Lines Inc.   4342.791836
# 12          Delta Air Lines Inc.   4575.015808
# 13             Endeavor Air Inc.   1812.536940
# 14                     Envoy Air   2067.896091
# 15      ExpressJet Airlines Inc.   4005.915751
# 16       ExpressJet Airlines LLC   1753.248062
# 17        Frontier Airlines Inc.   1782.225662
# 18        Hawaiian Airlines Inc.   1280.716401
# 19                   Horizon Air   1223.844869
# 20              Independence Air   3179.829851
# 21               JetBlue Airways   5430.483754
# 22            Mesa Airlines Inc.   2198.154526
# 23       Northwest Airlines Inc.   3664.677459
# 24             PSA Airlines Inc.   2495.529286
# 25        Pinnacle Airlines Inc.   1958.213864
# 26              Republic Airline   2920.191186
# 27         SkyWest Airlines Inc.   3328.616200
# 28        Southwest Airlines Co.  11242.021393
# 29              Spirit Air Lines   4336.106389
# 30               US Airways Inc.   4518.197250
# 31         United Air Lines Inc.   5979.190406
# 32                Virgin America   3435.455439

# %%
df.groupby("carrier_name")[["delay_rate"]].mean().reset_index()
# Out:
# C:\Users\tahim\AppData\Local\Temp\ipykernel_9636\3402215460.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("carrier_name")[["delay_rate"]].mean().reset_index()
#                     carrier_name  delay_rate
# 0         ATA Airlines d/b/a ATA    0.211270
# 1    AirTran Airways Corporation    0.199380
# 2           Alaska Airlines Inc.    0.161808
# 3                  Allegiant Air    0.191270
# 4            Aloha Airlines Inc.    0.114339
# 5     America West Airlines Inc.    0.225039
# 6         American Airlines Inc.    0.215371
# 7   American Eagle Airlines Inc.    0.228197
# 8        Atlantic Coast Airlines    0.222922
# 9    Atlantic Southeast Airlines    0.256382
# 10                   Comair Inc.    0.230587
# 11    Continental Air Lines Inc.    0.218932
# 12          Delta Air Lines Inc.    0.163749
# 13             Endeavor Air Inc.    0.125805
# 14                     Envoy Air    0.174746
# 15      ExpressJet Airlines Inc.    0.209801
# 16       ExpressJet Airlines LLC    0.182376
# 17        Frontier Airlines Inc.    0.223660
# 18        Hawaiian Airlines Inc.    0.167262
# 19                   Horizon Air    0.141784
# 20              Independence Air    0.220004
# 21               JetBlue Airways    0.228552
# 22            Mesa Airlines Inc.    0.197226
# 23       Northwest Airlines Inc.    0.248268
# 24             PSA Airlines Inc.    0.169054
# 25        Pinnacle Airlines Inc.    0.187157
# 26              Republic Airline    0.148505
# 27         SkyWest Airlines Inc.    0.176149
# 28        Southwest Airlines Co.    0.194113
# 29              Spirit Air Lines    0.188895
# 30               US Airways Inc.    0.197718
# 31         United Air Lines Inc.    0.207357
# 32                Virgin America    0.182437

# %% [markdown]
# ### B. Visualizations

# %% [markdown]
# 2 histograms

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5))
sns.histplot(x=np.log1p(df["arr_delay"]), bins=30)
plt.title("Histogram of Total Arrival Delay Minutes (Log Transformed)")
